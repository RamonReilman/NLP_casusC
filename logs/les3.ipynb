# %%
# %%bash
#
# wget -O cancer_vol1.txt https://www.gutenberg.org/cache/epub/15316/pg15316.txt
# wget -O cancer_vol2.txt https://www.gutenberg.org/cache/epub/15317/pg15317.txt
#
#
# cat cancer_vol1.txt cancer_vol2.txt > cancer_full.txt
# Out:
# --2025-12-11 00:09:11--  https://www.gutenberg.org/cache/epub/15316/pg15316.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 213445 (208K) [text/plain]
# Saving to: ‘cancer_vol1.txt’
#
#      0K .......... .......... .......... .......... .......... 23%  436K 0s
#     50K .......... .......... .......... .......... .......... 47%  484K 0s
#    100K .......... .......... .......... .......... .......... 71% 4.32M 0s
#    150K .......... .......... .......... .......... .......... 95%  518K 0s
#    200K ........                                              100% 4.35M=0.3s
#
# 2025-12-11 00:09:12 (636 KB/s) - ‘cancer_vol1.txt’ saved [213445/213445]
#
# --2025-12-11 00:09:12--  https://www.gutenberg.org/cache/epub/15317/pg15317.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 471795 (461K) [text/plain]
# Saving to: ‘cancer_vol2.txt’
#
#      0K .......... .......... .......... .......... .......... 10%  459K 1s
#     50K .......... .......... .......... .......... .......... 21%  476K 1s
#    100K .......... .......... .......... .......... .......... 32% 8.45M 0s
#    150K .......... .......... .......... .......... .......... 43%  485K 0s
#    200K .......... .......... .......... .......... .......... 54% 19.5M 0s
#    250K .......... .......... .......... .......... .......... 65% 15.6M 0s
#    300K .......... .......... .......... .......... .......... 75% 82.1M 0s
#    350K .......... .......... .......... .......... .......... 86% 30.3M 0s
#    400K .......... .......... .......... .......... .......... 97%  501K 0s
#    450K ..........                                            100%  159M=0.4s
#
# 2025-12-11 00:09:13 (1.05 MB/s) - ‘cancer_vol2.txt’ saved [471795/471795]

# %%
# %%bash
# python3 Tokenize.py generate-enc --txt_file cancer_full.txt --output cancer.enc -m 100

# %%
# %%bash
#
# python3 Tokenize.py generate-toc --txt_file cancer_full.txt --enc_file cancer.enc --output cancer.tok

# %%
# %%bash
#
#
# #  3-gram
# python3 Tokenisation_jarno.py ngram -n 3 -i cancer.tok -o gen_3gram.tok -l 100
# Out:
# Wrote output to 'gen_3gram.tok'

# %%
# %%bash
#
# python3 Tokenize.py generate-txt --tok_file gen_3gram.tok --enc_file cancer.enc --output out_3gram.txt
# head -c 200 out_3gram.txt
# Out:
# Parmalee to himself.  "I may as well do a little stroke of business, to
# keep my hand in, while I wait for my lady.  There ain't no telling how
# this little speculation of mine may turn out, after all."
